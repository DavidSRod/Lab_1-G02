# %%
goles_messi = 794
for gol in range(goles_messi):
  print('Viva Messi')
# Out:
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# ...
