# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSRod/Lab_1-G02/blob/Tobon/Lab1_G2_(Viva_Messi).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
goles_messi = 794
for gol in range(goles_messi):
  print('Viva Messi')

print('Camilo Vargas >>> Ospina')
# Out:
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# Viva Messi
# ...
